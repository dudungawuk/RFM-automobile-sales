# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data/Auto Sales data.csv")
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0     Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1    Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2       Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3     Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Technics Stores Inc.        6505556809              9408 Furth Circle
#
#          CITY POSTALCODE COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         NYC      10022     USA              Yu             Kwai    Small
# 1       Reims      51100  France         Henriot             Paul    Small
# 2       Paris      75508  France        Da Cunha           Daniel   Medium
# 3    Pasadena      90003     USA           Young            Julie   Medium
# 4  Burlingame      94217     USA          Hirano             Juri   Medium

# %% [markdown]
# ##
# - ORDERNUMBER	This column represents the unique identification number assigned to each order.
# - QUANTITYORDERED	It indicates the number of items ordered in each order.
# - PRICEEACH	This column specifies the price of each item in the order.
# - ORDERLINENUMBER	It represents the line number of each item within an order.
# - SALES	This column denotes the total sales amount for each order, which is calculated by multiplying the quantity ordered by the price of each item.
# - ORDERDATE	It denotes the date on which the order was placed.
# - DAYS_SINCE_LASTORDER	This column represents the number of days that have passed since the last order for each customer. It can be used to analyze customer purchasing patterns.
# - STATUS	It indicates the status of the order, such as "Shipped," "In Process," "Cancelled," "Disputed," "On Hold," or "Resolved."
# - PRODUCTLINE	This column specifies the product line categories to which each item belongs.
# - MSRP	It stands for Manufacturer's Suggested Retail Price and represents the suggested selling price for each item.
# - PRODUCTCODE	This column represents the unique code assigned to each product.
# - CUSTOMERNAME	It denotes the name of the customer who placed the order.
# - PHONE	This column contains the contact phone number for the customer.
# - ADDRESSLINE1	It represents the first line of the customer's address.
# - CITY	This column specifies the city where the customer is located.
# - POSTALCODE	It denotes the postal code or ZIP code associated with the customer's address.
# - COUNTRY	This column indicates the country where the customer is located.
# - CONTACTLASTNAME	It represents the last name of the contact person associated with the customer.
# - CONTACTFIRSTNAME	This column denotes the first name of the contact person associated with the customer.
# - DEALSIZE	It indicates the size of the deal or order, which are the categories "Small," "Medium," or "Large."

# %%
df.shape
# Out:
# (2747, 20)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
#  15  POSTALCODE            2747 non-null   object
#  16  COUNTRY               2747 non-null   object
#  17  CONTACTLASTNAME       2747 non-null   object
#  18  CONTACTFIRSTNAME      2747 non-null   object
#  19  DEALSIZE              2747 non-null   object
# dtypes: float64(2), int64(5), object(13)
# memory usage: 429.3+ KB

# %% [markdown]
# ###
# - Orderdate menggunakan datetime

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'], format='%d/%m/%Y')
df['ORDERDATE'].describe()
# Out:
# count                             2747
# mean     2019-05-13 21:56:17.211503360
# min                2018-01-06 00:00:00
# 25%                2018-11-08 00:00:00
# 50%                2019-06-24 00:00:00
# 75%                2019-11-17 00:00:00
# max                2020-05-31 00:00:00
# Name: ORDERDATE, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# 25%     2204.350000            2018-11-08 00:00:00           1077.000000
# 50%     3184.800000            2019-06-24 00:00:00           1761.000000
# 75%     4503.095000            2019-11-17 00:00:00           2436.500000
# max    14082.800000            2020-05-31 00:00:00           3562.000000
# std     1838.953901                            NaN            819.280576
#
#               MSRP
# count  2747.000000
# mean    100.691664
# min      33.000000
# 25%      68.000000
# 50%      99.000000
# 75%     124.000000
# max     214.000000
# std      40.114802

# %%
df[df["ORDERNUMBER"].duplicated()].sort_values(by="ORDERNUMBER",ascending = False).CUSTOMERNAME.nunique()
# Out:
# 89

# %% [markdown]
# ## Asumsikan jika disuruh membuat analisis RFM pada tanggal 2020-06-01

# %%
current_date = pd.to_datetime('2020-06-01')
current_date
# Out:
# Timestamp('2020-06-01 00:00:00')

# %% [markdown]
# ### Mengecek data kolom sales apakah sudah benar, seperti prich each * quantity = sales

# %%
df['SALES_CALCULATED'] = df['QUANTITYORDERED'] * df['PRICEEACH']
df['SALES_ROUND'] = df['SALES_CALCULATED'].round(2)  # Membulatkan ke dua desimal
df['SALES_ROUND'] = df['SALES_ROUND'].astype(str)  # Konversi ke string untuk pengecekan lebih mudah

# Cek perbedaan antara SALES yang sudah dibulatkan dan SALES yang tertera
df_invalid_sales = df[df['SALES'].astype(str) != df['SALES_ROUND']]
df_invalid_sales
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 41          10304               47     216.44                6  10172.7
# 42          10312               48     242.16                3  11623.7
# 1930        10405               76     154.47                3  11739.7
# 2049        10375               43     233.48                2  10039.6
# 2432        10388               46     218.84                2  10066.6
#
#       ORDERDATE  DAYS_SINCE_LASTORDER   STATUS   PRODUCTLINE  MSRP  ...  \
# 41   2019-10-11                   275  Shipped  Classic Cars   214  ...
# 42   2019-10-21                   266  Shipped  Classic Cars   214  ...
# 1930 2020-04-14                  1978  Shipped  Classic Cars   140  ...
# 2049 2020-02-03                  2168  Shipped        Planes    72  ...
# 2432 2020-03-03                  2522  Shipped        Planes    91  ...
#
#            PHONE                  ADDRESSLINE1         CITY POSTALCODE  \
# 41    30.59.8555        67, avenue de l'Europe   Versailles      78000
# 42    4155551450               5677 Strong St.   San Rafael      97562
# 1930  88.60.1555              24, place Kluber   Strasbourg      67000
# 2049  40.67.8555  67, rue des Cinquante Otages       Nantes      44000
# 2432  5085552555             1785 First Street  New Bedford      50553
#
#      COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE SALES_CALCULATED  \
# 41    France          Tonini           Daniel    Large         10172.68
# 42       USA          Nelson          Valarie    Large         11623.68
# 1930  France         Citeaux       Frederique    Large         11739.72
# 2049  France         Labrune           Janine    Large         10039.64
# 2432     USA         Benitez          Violeta    Large         10066.64
#
#      SALES_ROUND
# 41      10172.68
# 42      11623.68
# 1930    11739.72
# 2049    10039.64
# 2432    10066.64
#
# [5 rows x 22 columns]

# %%
df.groupby(["CUSTOMERNAME","ORDERNUMBER"])["PRODUCTLINE"].unique().reset_index()
# Out:
#                     CUSTOMERNAME  ORDERNUMBER  \
# 0                 AV Stores, Co.        10110
# 1                 AV Stores, Co.        10306
# 2                 AV Stores, Co.        10332
# 3                   Alpha Cognac        10136
# 4                   Alpha Cognac        10178
# ..                           ...          ...
# 293     Volvo Model Replicas, Co        10334
# 294  West Coast Collectables Co.        10199
# 295  West Coast Collectables Co.        10215
# 296            giftsbymail.co.uk        10232
# 297            giftsbymail.co.uk        10316
#
#                                         PRODUCTLINE
# 0                      [Classic Cars, Vintage Cars]
# 1       [Classic Cars, Vintage Cars, Trains, Ships]
# 2                      [Vintage Cars, Classic Cars]
# 3                                    [Classic Cars]
# 4       [Classic Cars, Planes, Ships, Vintage Cars]
# ..                                              ...
# 293                [Classic Cars, Trucks and Buses]
# 294                          [Vintage Cars, Planes]
# 295  [Classic Cars, Trucks and Buses, Vintage Cars]
# 296                   [Vintage Cars, Trains, Ships]
# 297     [Classic Cars, Planes, Ships, Vintage Cars]
#
# [298 rows x 3 columns]

# %%
df[df["ORDERNUMBER"] == 10306]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 190         10306               31     211.96               13  6570.76
# 266         10306               34     146.55               14  4982.70
# 315         10306               20     181.67               12  3633.40
# 963         10306               32     117.47                9  3759.04
# 1039        10306               40      91.76               11  3670.40
# 1209        10306               23     156.55               16  3600.65
# 1257        10306               39      90.40                8  3525.60
# 1552        10306               29     110.60                7  3207.40
# 1776        10306               31      84.08                2  2606.48
# 2196        10306               46      50.33               17  2315.18
# 2350        10306               34      60.34               15  2051.56
# 2401        10306               50      54.00                3  2700.00
# 2452        10306               38      91.81               10  3488.78
# 2530        10306               43      75.17                1  3232.31
# 2633        10306               32      90.15                4  2884.80
# 2659        10306               30     117.19                5  3515.70
# 2738        10306               35      59.51                6  2082.85
#
#       ORDERDATE  DAYS_SINCE_LASTORDER   STATUS   PRODUCTLINE  MSRP  ...  \
# 190  2019-10-14                   421  Shipped  Classic Cars   207  ...
# 266  2019-10-14                   497  Shipped  Classic Cars   151  ...
# 315  2019-10-14                   546  Shipped  Classic Cars   173  ...
# 963  2019-10-14                  1194  Shipped  Vintage Cars   136  ...
# 1039 2019-10-14                  1270  Shipped        Trains   100  ...
# 1209 2019-10-14                  1440  Shipped  Classic Cars   143  ...
# 1257 2019-10-14                  1488  Shipped  Vintage Cars    87  ...
# 1552 2019-10-14                  1783  Shipped         Ships   122  ...
# 1776 2019-10-14                  2007  Shipped  Vintage Cars    88  ...
# 2196 2019-10-14                  2427  Shipped        Trains    62  ...
# 2350 2019-10-14                  2581  Shipped        Trains    58  ...
# 2401 2019-10-14                  2632  Shipped         Ships    66  ...
# 2452 2019-10-14                  2683  Shipped         Ships    86  ...
# 2530 2019-10-14                  2761  Shipped         Ships    72  ...
# 2633 2019-10-14                  2864  Shipped         Ships   100  ...
# 2659 2019-10-14                  2890  Shipped         Ships    99  ...
# 2738 2019-10-14                  2969  Shipped         Ships    54  ...
#
#                PHONE       ADDRESSLINE1        CITY POSTALCODE COUNTRY  \
# 190   (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 266   (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 315   (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 963   (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 1039  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 1209  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 1257  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 1552  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 1776  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2196  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2350  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2401  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2452  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2530  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2633  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2659  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
# 2738  (171) 555-1555  Fauntleroy Circus  Manchester    EC2 5NT      UK
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE SALES_CALCULATED SALES_ROUND
# 190         Ashworth         Victoria   Medium          6570.76     6570.76
# 266         Ashworth         Victoria   Medium          4982.70      4982.7
# 315         Ashworth         Victoria   Medium          3633.40      3633.4
# 963         Ashworth         Victoria   Medium          3759.04     3759.04
# 1039        Ashworth         Victoria   Medium          3670.40      3670.4
# 1209        Ashworth         Victoria   Medium          3600.65     3600.65
# 1257        Ashworth         Victoria   Medium          3525.60      3525.6
# 1552        Ashworth         Victoria   Medium          3207.40      3207.4
# 1776        Ashworth         Victoria    Small          2606.48     2606.48
# 2196        Ashworth         Victoria    Small          2315.18     2315.18
# 2350        Ashworth         Victoria    Small          2051.56     2051.56
# 2401        Ashworth         Victoria    Small          2700.00      2700.0
# 2452        Ashworth         Victoria   Medium          3488.78     3488.78
# 2530        Ashworth         Victoria   Medium          3232.31     3232.31
# 2633        Ashworth         Victoria    Small          2884.80      2884.8
# 2659        Ashworth         Victoria   Medium          3515.70      3515.7
# 2738        Ashworth         Victoria    Small          2082.85     2082.85
#
# [17 rows x 22 columns]

# %%
df.SALES.sum() - df.SALES_CALCULATED.sum()
# Out:
# -0.06000000052154064

# %%
df[df["SALES"] != df["QUANTITYORDERED"] * df["PRICEEACH"]]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# 7           10211               41     114.84               14  4708.44
# ...           ...              ...        ...              ...      ...
# 2733        10248               23      65.52                9  1506.96
# 2734        10261               29      50.78                7  1472.62
# 2740        10327               37      86.74                4  3209.38
# 2743        10373               29     137.19                1  3978.51
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER     STATUS  PRODUCTLINE  MSRP  ...  \
# 1    2018-05-07                   757    Shipped  Motorcycles    95  ...
# 2    2018-07-01                   703    Shipped  Motorcycles    95  ...
# 3    2018-08-25                   649    Shipped  Motorcycles    95  ...
# 4    2018-10-28                   586    Shipped  Motorcycles    95  ...
# 7    2019-01-15                   510    Shipped  Motorcycles    95  ...
# ...         ...                   ...        ...          ...   ...  ...
# 2733 2019-05-07                  3124  Cancelled        Ships    54  ...
# 2734 2019-06-17                  3084    Shipped        Ships    54  ...
# 2740 2019-11-10                  2944   Resolved        Ships    54  ...
# 2743 2020-01-31                  2865    Shipped        Ships    54  ...
# 2746 2020-05-06                  2772    On Hold        Ships    54  ...
#
#                  PHONE                   ADDRESSLINE1        CITY POSTALCODE  \
# 1           26.47.1555             59 rue de l'Abbaye       Reims      51100
# 2     +33 1 46 62 7555  27 rue du Colonel Pierre Avia       Paris      75508
# 3           6265557265             78934 Hillside Dr.    Pasadena      90003
# 4           6505556809              9408 Furth Circle  Burlingame      94217
# 7       (1) 47.55.6555              25, rue Lauriston       Paris      75016
# ...                ...                            ...         ...        ...
# 2733        2125557818        897 Long Airport Avenue         NYC      10022
# 2734    (514) 555-8054             43 rue St. Laurent    Montreal    H1J 1C3
# 2740        31 12 3555                   Vinb'ltet 34   Kobenhavn       1734
# 2743        981-443655                    Torikatu 38        Oulu      90110
# 2746        6175559555             8616 Spinnaker Dr.      Boston      51003
#
#       COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE SALES_CALCULATED  \
# 1      France         Henriot             Paul    Small          2765.90
# 2      France        Da Cunha           Daniel   Medium          3884.34
# 3         USA           Young            Julie   Medium          3746.70
# 4         USA          Hirano             Juri   Medium          3479.76
# 7      France         Perrier        Dominique   Medium          4708.44
# ...       ...             ...              ...      ...              ...
# 2733      USA              Yu             Kwai    Small          1506.96
# 2734   Canada       Fresnisre             Jean    Small          1472.62
# 2740  Denmark        Petersen            Jytte   Medium          3209.38
# 2743  Finland       Koskitalo           Pirkko   Medium          3978.51
# 2746      USA         Yoshido             Juri   Medium          3079.44
#
#      SALES_ROUND
# 1         2765.9
# 2        3884.34
# 3         3746.7
# 4        3479.76
# 7        4708.44
# ...          ...
# 2733     1506.96
# 2734     1472.62
# 2740     3209.38
# 2743     3978.51
# 2746     3079.44
#
# [702 rows x 22 columns]

# %% [markdown]
# ### mengelompokan data sesuai kebutuhan untuk RFM

# %%
df_rfm = df[["CUSTOMERNAME","ORDERDATE","SALES"]].copy()

# %%
df_rfm
# Out:
#                  CUSTOMERNAME  ORDERDATE    SALES
# 0           Land of Toys Inc. 2018-02-24  2871.00
# 1          Reims Collectables 2018-05-07  2765.90
# 2             Lyon Souveniers 2018-07-01  3884.34
# 3           Toys4GrownUps.com 2018-08-25  3746.70
# 4        Technics Stores Inc. 2018-10-28  3479.76
# ...                       ...        ...      ...
# 2742    Euro Shopping Channel 2019-12-02  2244.40
# 2743  Oulu Toy Supplies, Inc. 2020-01-31  3978.51
# 2744    Euro Shopping Channel 2020-03-01  5417.57
# 2745             Alpha Cognac 2020-03-28  2116.16
# 2746        Gifts4AllAges.com 2020-05-06  3079.44
#
# [2747 rows x 3 columns]

# %%
df_rfm["RECENCY"] = (current_date - df_rfm["ORDERDATE"]).dt.days

# %%
df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CUSTOMERNAME  2747 non-null   object
#  1   ORDERDATE     2747 non-null   datetime64[ns]
#  2   SALES         2747 non-null   float64
#  3   RECENCY       2747 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 86.0+ KB

# %%
df_rfm["RECENCY"].describe()
# Out:
# count    2747.000000
# mean      384.085912
# std       230.231295
# min         1.000000
# 25%       197.000000
# 50%       343.000000
# 75%       571.000000
# max       877.000000
# Name: RECENCY, dtype: float64

# %% [markdown]
# # insight
# mean = 180.61: Rata-rata recency adalah sekitar 181 hari, yang menunjukkan bahwa, secara rata-rata, pelanggan terakhir melakukan pembelian sekitar 6 bulan yang lalu.
# std = 128.89: Standar deviasi yang relatif tinggi menunjukkan bahwa ada variasi yang signifikan dalam recency, dengan beberapa pelanggan yang melakukan pembelian baru-baru ini dan lainnya sudah lebih lama tidak bertransaksi.
# min = 1: Nilai minimum adalah 1, yang berarti ada pelanggan yang baru saja melakukan pembelian.
# 25% = 76: Artinya 25% pelanggan terakhir melakukan pembelian dalam waktu kurang dari 76 hari yang lalu.
# 50% = 185: Nilai median (50%) adalah 185 hari, yang berarti setengah dari pelanggan terakhir melakukan pembelian dalam 185 hari terakhir.
# 75% = 231: 75% pelanggan terakhir melakukan pembelian dalam waktu kurang dari 231 hari yang lalu.
# max = 496: Nilai maksimum adalah 496 hari, yang berarti ada pelanggan yang terakhir kali membeli produk sekitar 16 bulan yang lalu.

# %% [markdown]
# ### group dari waktu terakhir kali setiap pelanggan melakukan pembelian

# %% [markdown]
# ### insihgt
# count = 2747: Terdapat 2,747 baris data dalam kolom RECENCY, yang berarti semua baris sudah dihitung dan tidak ada nilai yang hilang (missing).
# mean = 384.08: Rata-rata recency adalah sekitar 384 hari. Ini berarti, secara rata-rata, pelanggan terakhir melakukan transaksi sekitar 384 hari yang lalu.
# std = 230.23: Standar deviasi yang cukup tinggi menunjukkan bahwa ada variasi yang cukup besar dalam nilai recency. Beberapa pelanggan melakukan pembelian baru-baru ini, sementara yang lain mungkin sudah lama tidak bertransaksi.
# min = 1: Nilai minimum adalah 1, yang berarti ada pelanggan yang baru saja melakukan pembelian.
# 25% = 197: Artinya 25% pelanggan terakhir melakukan pembelian dalam waktu kurang dari 197 hari.
# 50% = 343: Nilai median (50%) adalah 343 hari, yang berarti setengah dari pelanggan terakhir melakukan pembelian dalam 343 hari terakhir.
# 75% = 571: 75% pelanggan terakhir melakukan pembelian dalam waktu kurang dari 571 hari.
# max = 877: Nilai maksimum adalah 877 hari, yang berarti ada pelanggan yang terakhir kali membeli produk sekitar 2 tahun dan 5 bulan yang lalu.

# %%
df_order_nunique = df.groupby("CUSTOMERNAME")["ORDERNUMBER"].nunique().reset_index()
df_order_nunique.rename(columns={"ORDERNUMBER" : "FREQUENCY"}, inplace = True)
df_rfm = df_rfm.merge(df_order_nunique, on="CUSTOMERNAME", how="left")
df_order_nunique.FREQUENCY.sum()
# Out:
# 298

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP  ...  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95  ...
# 1 2018-05-07                   757  Shipped  Motorcycles    95  ...
# 2 2018-07-01                   703  Shipped  Motorcycles    95  ...
# 3 2018-08-25                   649  Shipped  Motorcycles    95  ...
# 4 2018-10-28                   586  Shipped  Motorcycles    95  ...
#
#               PHONE                   ADDRESSLINE1        CITY POSTALCODE  \
# 0        2125557818        897 Long Airport Avenue         NYC      10022
# 1        26.47.1555             59 rue de l'Abbaye       Reims      51100
# 2  +33 1 46 62 7555  27 rue du Colonel Pierre Avia       Paris      75508
# 3        6265557265             78934 Hillside Dr.    Pasadena      90003
# 4        6505556809              9408 Furth Circle  Burlingame      94217
#
#   COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE SALES_CALCULATED  \
# 0     USA              Yu             Kwai    Small          2871.00
# 1  France         Henriot             Paul    Small          2765.90
# 2  France        Da Cunha           Daniel   Medium          3884.34
# 3     USA           Young            Julie   Medium          3746.70
# 4     USA          Hirano             Juri   Medium          3479.76
#
#   SALES_ROUND
# 0      2871.0
# 1      2765.9
# 2     3884.34
# 3      3746.7
# 4     3479.76
#
# [5 rows x 22 columns]

# %%
df_frequency = df.groupby("CUSTOMERNAME")["ORDERNUMBER"].nunique().reset_index()
df_frequency["FREQUENCY"] = df_frequency["ORDERNUMBER"]
df_frequency = df_frequency.drop(columns ="ORDERNUMBER")
df_frequency
# Out:
#                    CUSTOMERNAME  FREQUENCY
# 0                AV Stores, Co.          3
# 1                  Alpha Cognac          3
# 2            Amica Models & Co.          2
# 3       Anna's Decorations, Ltd          4
# 4             Atelier graphique          3
# ..                          ...        ...
# 84              Vida Sport, Ltd          2
# 85              Vitachrome Inc.          3
# 86     Volvo Model Replicas, Co          4
# 87  West Coast Collectables Co.          2
# 88            giftsbymail.co.uk          2
#
# [89 rows x 2 columns]

# %%
df["RECENCY"] = (current_date - df["ORDERDATE"]).dt.days

# %%
df_recency = df.groupby("CUSTOMERNAME")["RECENCY"].min().reset_index()
df_recency
# Out:
#                    CUSTOMERNAME  RECENCY
# 0                AV Stores, Co.      197
# 1                  Alpha Cognac       65
# 2            Amica Models & Co.      266
# 3       Anna's Decorations, Ltd       84
# 4             Atelier graphique      189
# ..                          ...      ...
# 84              Vida Sport, Ltd      276
# 85              Vitachrome Inc.      209
# 86     Volvo Model Replicas, Co      195
# 87  West Coast Collectables Co.      489
# 88            giftsbymail.co.uk      213
#
# [89 rows x 2 columns]

# %%
df_monetary = df.groupby("CUSTOMERNAME")["SALES"].sum().reset_index()
df_monetary.rename(columns={"SALES" : "MONETARY"}, inplace = True)
df_monetary
# Out:
#                    CUSTOMERNAME   MONETARY
# 0                AV Stores, Co.  157807.81
# 1                  Alpha Cognac   70488.44
# 2            Amica Models & Co.   94117.26
# 3       Anna's Decorations, Ltd  153996.13
# 4             Atelier graphique   24179.96
# ..                          ...        ...
# 84              Vida Sport, Ltd  117713.56
# 85              Vitachrome Inc.   88041.26
# 86     Volvo Model Replicas, Co   75754.88
# 87  West Coast Collectables Co.   46084.64
# 88            giftsbymail.co.uk   78240.84
#
# [89 rows x 2 columns]

# %%
df_rfm = df_recency.merge(df_frequency, on="CUSTOMERNAME", how="left")\
                   .merge(df_monetary, on="CUSTOMERNAME", how="left")

# %%
df_rfm
# Out:
#                    CUSTOMERNAME  RECENCY  FREQUENCY   MONETARY
# 0                AV Stores, Co.      197          3  157807.81
# 1                  Alpha Cognac       65          3   70488.44
# 2            Amica Models & Co.      266          2   94117.26
# 3       Anna's Decorations, Ltd       84          4  153996.13
# 4             Atelier graphique      189          3   24179.96
# ..                          ...      ...        ...        ...
# 84              Vida Sport, Ltd      276          2  117713.56
# 85              Vitachrome Inc.      209          3   88041.26
# 86     Volvo Model Replicas, Co      195          4   75754.88
# 87  West Coast Collectables Co.      489          2   46084.64
# 88            giftsbymail.co.uk      213          2   78240.84
#
# [89 rows x 4 columns]

# %%
df_rfm["RECENCY"].describe()
# Out:
# count     89.000000
# mean     180.606742
# std      128.893862
# min        1.000000
# 25%       76.000000
# 50%      185.000000
# 75%      231.000000
# max      496.000000
# Name: RECENCY, dtype: float64

# %%
def frequency_distribution(data, bins):
    intervals = pd.cut(data, bins=range(0, int(data.max()) + bins, bins))
    
    frequency = intervals.value_counts().sort_index()
    
    print(frequency)

frequency_distribution(df_rfm["RECENCY"], 50)
# Out:
# RECENCY
# (0, 50]       17
# (50, 100]     11
# (100, 150]    11
# (150, 200]    15
# (200, 250]    16
# (250, 300]     8
# (300, 350]     0
# (350, 400]     2
# (400, 450]     3
# (450, 500]     6
# Name: count, dtype: int64

# %%
plt.hist(df_rfm["RECENCY"])
plt.title("Recency Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_rfm["RECENCY_SEGMENTATION"] = df_rfm["RECENCY"].apply(lambda x: "Recent Customes" if x <=50 else "Active Customer" if x <=200 else "At Risk Customer" if x <= 350 else "Inactive Customer")

# %%
df_rfm
# Out:
#                    CUSTOMERNAME  RECENCY  FREQUENCY   MONETARY  \
# 0                AV Stores, Co.      197          3  157807.81
# 1                  Alpha Cognac       65          3   70488.44
# 2            Amica Models & Co.      266          2   94117.26
# 3       Anna's Decorations, Ltd       84          4  153996.13
# 4             Atelier graphique      189          3   24179.96
# ..                          ...      ...        ...        ...
# 84              Vida Sport, Ltd      276          2  117713.56
# 85              Vitachrome Inc.      209          3   88041.26
# 86     Volvo Model Replicas, Co      195          4   75754.88
# 87  West Coast Collectables Co.      489          2   46084.64
# 88            giftsbymail.co.uk      213          2   78240.84
#
#    RECENCY_SEGMENTATION
# 0       Active Customer
# 1       Active Customer
# 2      At Risk Customer
# 3       Active Customer
# 4       Active Customer
# ..                  ...
# 84     At Risk Customer
# 85     At Risk Customer
# 86      Active Customer
# 87    Inactive Customer
# 88     At Risk Customer
#
# [89 rows x 5 columns]

# %%
df_rfm["FREQUENCY"].describe()
# Out:
# count    89.000000
# mean      3.348315
# std       2.969929
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max      26.000000
# Name: FREQUENCY, dtype: float64

# %%
frequency_distribution(df_rfm["FREQUENCY"], 1)
# Out:
# FREQUENCY
# (0, 1]       1
# (1, 2]      27
# (2, 3]      40
# (3, 4]      15
# (4, 5]       4
# (5, 6]       0
# (6, 7]       0
# (7, 8]       0
# (8, 9]       0
# (9, 10]      0
# (10, 11]     0
# (11, 12]     0
# (12, 13]     0
# (13, 14]     0
# (14, 15]     0
# (15, 16]     0
# (16, 17]     1
# (17, 18]     0
# (18, 19]     0
# (19, 20]     0
# (20, 21]     0
# (21, 22]     0
# (22, 23]     0
# (23, 24]     0
# (24, 25]     0
# (25, 26]     1
# Name: count, dtype: int64

# %%
plt.hist(df_rfm["FREQUENCY"])
plt.title("Frequency Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_rfm["FREQUENCY_SEGMENTATION"] = df_rfm["FREQUENCY"].apply(lambda x: "Low Frequency" if x <=2 else "Medium Frequency" if x <=5 else "High Frequency" )

# %%
df_rfm
# Out:
#                    CUSTOMERNAME  RECENCY  FREQUENCY   MONETARY  \
# 0                AV Stores, Co.      197          3  157807.81
# 1                  Alpha Cognac       65          3   70488.44
# 2            Amica Models & Co.      266          2   94117.26
# 3       Anna's Decorations, Ltd       84          4  153996.13
# 4             Atelier graphique      189          3   24179.96
# ..                          ...      ...        ...        ...
# 84              Vida Sport, Ltd      276          2  117713.56
# 85              Vitachrome Inc.      209          3   88041.26
# 86     Volvo Model Replicas, Co      195          4   75754.88
# 87  West Coast Collectables Co.      489          2   46084.64
# 88            giftsbymail.co.uk      213          2   78240.84
#
#    RECENCY_SEGMENTATION FREQUENCY_SEGMENTATION
# 0       Active Customer       Medium Frequency
# 1       Active Customer       Medium Frequency
# 2      At Risk Customer          Low Frequency
# 3       Active Customer       Medium Frequency
# 4       Active Customer       Medium Frequency
# ..                  ...                    ...
# 84     At Risk Customer          Low Frequency
# 85     At Risk Customer       Medium Frequency
# 86      Active Customer       Medium Frequency
# 87    Inactive Customer          Low Frequency
# 88     At Risk Customer          Low Frequency
#
# [89 rows x 6 columns]

# %%
df_rfm["MONETARY"].describe()
# Out:
# count        89.000000
# mean     109665.412472
# std      111837.420467
# min        9129.350000
# 25%       70488.440000
# 50%       87489.230000
# 75%      120562.740000
# max      912294.110000
# Name: MONETARY, dtype: float64

# %%
frequency_distribution(df_rfm["MONETARY"], 50000)
# Out:
# MONETARY
# (0, 50000]          10
# (50000, 100000]     42
# (100000, 150000]    26
# (150000, 200000]     8
# (200000, 250000]     1
# (250000, 300000]     0
# (300000, 350000]     0
# (350000, 400000]     0
# (400000, 450000]     0
# (450000, 500000]     0
# (500000, 550000]     0
# (550000, 600000]     0
# (600000, 650000]     0
# (650000, 700000]     1
# (700000, 750000]     0
# (750000, 800000]     0
# (800000, 850000]     0
# (850000, 900000]     0
# (900000, 950000]     1
# Name: count, dtype: int64

# %%
plt.hist(df_rfm["MONETARY"])
plt.title("Monetary Distribution")
# Out:
# Text(0.5, 1.0, 'Monetary Distribution')

# %%
df_rfm["MONETARY_DISTRIBUTION"] = df_rfm["MONETARY"].apply(lambda x: "Low Spending" if x <=50000 else "Moderate Spending" if x <=150000 else "High Spending")

# %%
df_rfm[df_rfm["MONETARY_DISTRIBUTION"] == "High Spending"]
# Out:
#                     CUSTOMERNAME  RECENCY  FREQUENCY   MONETARY  \
# 0                 AV Stores, Co.      197          3  157807.81
# 3        Anna's Decorations, Ltd       84          4  153996.13
# 6     Australian Collectors, Co.      185          5  200995.41
# 30       Dragon Souveniers, Ltd.       91          5  172989.68
# 32         Euro Shopping Channel        1         26  912294.11
# 43             La Rochelle Gifts        1          4  180124.90
# 44             Land of Toys Inc.      199          4  164069.44
# 53  Mini Gifts Distributors Ltd.        3         17  654858.06
# 55            Muscle Machine Inc      183          4  197736.94
# 72     Souveniers And Things Co.        3          4  151570.98
# 78     The Sharp Gifts Warehouse       40          4  160010.27
#
#    RECENCY_SEGMENTATION FREQUENCY_SEGMENTATION MONETARY_DISTRIBUTION
# 0       Active Customer       Medium Frequency         High Spending
# 3       Active Customer       Medium Frequency         High Spending
# 6       Active Customer       Medium Frequency         High Spending
# 30      Active Customer       Medium Frequency         High Spending
# 32      Recent Customes         High Frequency         High Spending
# 43      Recent Customes       Medium Frequency         High Spending
# 44      Active Customer       Medium Frequency         High Spending
# 53      Recent Customes         High Frequency         High Spending
# 55      Active Customer       Medium Frequency         High Spending
# 72      Recent Customes       Medium Frequency         High Spending
# 78      Recent Customes       Medium Frequency         High Spending
